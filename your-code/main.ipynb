# %% [markdown]
# # Installing Spotipy

# %%
#!pip install spotipy

# %% [markdown]
# ## Loading credentials from the config file

# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %% [markdown]
# #### Make sure that you have stored your spotify client_id and client_secret in a separate config.py file
# #### Once that's done, we import it

# %%
client_id = os.getenv("SPOTIFY_CLIENT_ID")
client_secret = os.getenv("SPOTIFY_CLIENT_SECRET")

# %% [markdown]
# ## Starting with Spotify API

# %%
import spotipy
import pandas as pd
import json
from spotipy.oauth2 import SpotifyClientCredentials



sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

print("SpotiPy  initialized successfully.")
# Out:
# SpotiPy  initialized successfully.

# %% [markdown]
# # Understanding the json

# %%
results = sp.search(q="2024 Top 100 Germany", type="playlist", limit=10 )

print(json.dumps(results, indent=2, ensure_ascii=False))
# Out:
# {
#   "playlists": {
#     "href": "https://api.spotify.com/v1/search?offset=0&limit=10&query=2024%20Top%20100%20Germany&type=playlist",
#     "limit": 10,
#     "next": "https://api.spotify.com/v1/search?offset=10&limit=10&query=2024%20Top%20100%20Germany&type=playlist",
#     "offset": 0,
#     "previous": null,
#     "total": 805,
#     "items": [
#       {
#         "collaborative": false,
#         "description": "CHARTS APRIL 2025 APRIL TOP 100 SINGLE CHARTS DEUTSCHLAND SONGS GERMANY CHARTS GERMANY TOP 50 CHARTS RADIO SONGS RADIO LIEDER CHART TOPPERS  LATEST HITS  EDM APRIL 2025 NEW MUSIC FRIDAY AYLIVA DANCE POP HITS 2025 BILLBOARD CHARTS DJ SONGS 2025 TRENDING MUSIC 2025 ARBEIT MUSIK MUSIK ZUM ARBEIT",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/5CiverItIyXTNNfYLXC01c"
#         },
#         "href": "https://api.spotify.com/v1/playlists/5CiverItIyXTNNfYLXC01c",
#         "id": "5CiverItIyXTNNfYLXC01c",
#         "images": [
#           {
#             "height": null,
#             "url": "https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84b0518a3199d1ee3d3b023605",
#             "width": null
#           }
#         ],
#         "name": "CHARTS APRIL  2025",
#         "owner": {
#           "display_name": "CHAPTER EIGHT",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/wtqcx4bhr0878brhugiqm5ms2"
#           },
#           "href": "https://api.spotify.com/v1/users/wtqcx4bhr0878brhugiqm5ms2",
#           "id": "wtqcx4bhr0878brhugiqm5ms2",
#           "type": "user",
#           "uri": "spotify:user:wtqcx4bhr0878brhugiqm5ms2"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AAAFHwFz89GDCmDUi2h9MtEr0B4mtnZy",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/5CiverItIyXTNNfYLXC01c/tracks",
#           "total": 60
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:5CiverItIyXTNNfYLXC01c"
#       },
#       null,
#       {
#         "collaborative": false,
#         "description": "<a href=\"https://bit.ly/3YdC68w\">Hier klicken für alle Jahrescharts · </a>  Top 100 Jahrescharts Deutschland · Germany Single Charts Top 100 2004 · veröffentlicht am 06.12.2024 · Erfolgreichste Songs 2024 · Deutsche Charts früher",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/2ZSsc7fFT7J9GQbanZu29P"
#         },
#         "href": "https://api.spotify.com/v1/playlists/2ZSsc7fFT7J9GQbanZu29P",
#         "id": "2ZSsc7fFT7J9GQbanZu29P",
#         "images": [
#           {
#             "height": null,
#             "url": "https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84dd1d894106964654880b45da",
#             "width": null
#           }
#         ],
#         "name": "Jahrescharts 2024 - Die Hits des Jahres · offizielle Top 100 Single-Charts 2024",
#         "owner": {
#           "display_name": "my.charts.music",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/teage03"
#           },
#           "href": "https://api.spotify.com/v1/users/teage03",
#           "id": "teage03",
#           "type": "user",
#           "uri": "spotify:user:teage03"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AAABGRb2Mh9VIdqsReEsfJMOnfR82JqU",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/2ZSsc7fFT7J9GQbanZu29P/tracks",
#           "total": 100
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:2ZSsc7fFT7J9GQbanZu29P"
#       },
#       {
#         "collaborative": false,
#         "description": "Entdecke die ultimative Playlist mit den heißesten und neuesten Hits! Hier findest du alle Top-Songs aus dem Radio und den Charts, einschließlich Nina Chuba, Apache207, Miley Cyrus, Harry Styles und vielen anderen.",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/1CnDCN10TJZjw6K2H3gNRv"
#         },
#         "href": "https://api.spotify.com/v1/playlists/1CnDCN10TJZjw6K2H3gNRv",
#         "id": "1CnDCN10TJZjw6K2H3gNRv",
#         "images": [
#           {
#             "height": null,
#             "url": "https://image-cdn-ak.spotifycdn.com/image/ab67706c0000d72c90c887497a88a92828e96420",
#             "width": null
#           }
#         ],
#         "name": "Hits 2025 🔥 🔥  Aktuelle Charts und die besten Songs 2025 🔝 🙌",
#         "owner": {
#           "display_name": "Filtr Germany",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/playlists.germany"
#           },
#           "href": "https://api.spotify.com/v1/users/playlists.germany",
#           "id": "playlists.germany",
#           "type": "user",
#           "uri": "spotify:user:playlists.germany"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AAACoSbYlfc2pbiraOobg1YxXtp3QHdt",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/1CnDCN10TJZjw6K2H3gNRv/tracks",
#           "total": 131
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:1CnDCN10TJZjw6K2H3gNRv"
#       },
#       {
#         "collaborative": false,
#         "description": "Radio Top 100 Germany - REL Top 40, FFH iTunes, Radio Harmony Top 40, Spotifý . Enjoy, DJ OKAY 14 - More Playlists from me: write &quot; DJ OKAY 14&quot; in search, and hit playlists on all ... Radio Top 40 , Party Dance Music , NDW - Neue Deutsche Welle , Summer Cocktail Party",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/2jn393YA9LPM9o5I4rzfqD"
#         },
#         "href": "https://api.spotify.com/v1/playlists/2jn393YA9LPM9o5I4rzfqD",
#         "id": "2jn393YA9LPM9o5I4rzfqD",
#         "images": [
#           {
#             "height": null,
#             "url": "https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84b42d7678ed3302de5329fd58",
#             "width": null
#           }
#         ],
#         "name": "Radio Top  100 Germany 🎸 🎵  Airplay Charts 01.09.2024 REL, FFH iTunes, Harmony, Spotifý. DJ OKAY 14 ",
#         "owner": {
#           "display_name": "DJ OKAY 14",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/hvqquw1espbvye62jsalupef6"
#           },
#           "href": "https://api.spotify.com/v1/users/hvqquw1espbvye62jsalupef6",
#           "id": "hvqquw1espbvye62jsalupef6",
#           "type": "user",
#           "uri": "spotify:user:hvqquw1espbvye62jsalupef6"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AAAWWJVmIxLfjFSk0L99jRLiiDXZVqWw",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/2jn393YA9LPM9o5I4rzfqD/tracks",
#           "total": 93
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:2jn393YA9LPM9o5I4rzfqD"
#       },
#       {
#         "collaborative": false,
#         "description": "Top 100 Germany Song Charts - Jeden Freitag aktuell. Wöchentliche, mengenbasierte Rangfolge der relevantesten Songs in Deutschland. Mehr auf mister-mixmania.com + News",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/46w2ClivIbhMgdqyGSKwvY"
#         },
#         "href": "https://api.spotify.com/v1/playlists/46w2ClivIbhMgdqyGSKwvY",
#         "id": "46w2ClivIbhMgdqyGSKwvY",
#         "images": [
#           {
#             "height": null,
#             "url": "https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84426930c613ad06cee55fc64c",
#             "width": null
#           }
#         ],
#         "name": "Top 100 Germany Single - Song Charts vom 18.04.25",
#         "owner": {
#           "display_name": "Mister Mixmania",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/r26v0qtkcxs6q96mreuaa3mzs"
#           },
#           "href": "https://api.spotify.com/v1/users/r26v0qtkcxs6q96mreuaa3mzs",
#           "id": "r26v0qtkcxs6q96mreuaa3mzs",
#           "type": "user",
#           "uri": "spotify:user:r26v0qtkcxs6q96mreuaa3mzs"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AAAEinT0Y1jwIjOUnbHQ0w6Bm9QfUvh5",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/46w2ClivIbhMgdqyGSKwvY/tracks",
#           "total": 100
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:46w2ClivIbhMgdqyGSKwvY"
#       },
#       {
#         "collaborative": false,
#         "description": "Song &#x2F; Single Charts - Das war 2024",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/48ovXYknwnw8ZLShQXgLOl"
#         },
#         "href": "https://api.spotify.com/v1/playlists/48ovXYknwnw8ZLShQXgLOl",
#         "id": "48ovXYknwnw8ZLShQXgLOl",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://mosaic.scdn.co/640/ab67616d00001e0249188fe723e4734b391f5162ab67616d00001e0272f356a0bf4ec66643e39516ab67616d00001e029a903819d8a5d3c80c47734cab67616d00001e02bef221ea02a821e7feeda9cf",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://mosaic.scdn.co/300/ab67616d00001e0249188fe723e4734b391f5162ab67616d00001e0272f356a0bf4ec66643e39516ab67616d00001e029a903819d8a5d3c80c47734cab67616d00001e02bef221ea02a821e7feeda9cf",
#             "width": 300
#           },
#           {
#             "height": 60,
#             "url": "https://mosaic.scdn.co/60/ab67616d00001e0249188fe723e4734b391f5162ab67616d00001e0272f356a0bf4ec66643e39516ab67616d00001e029a903819d8a5d3c80c47734cab67616d00001e02bef221ea02a821e7feeda9cf",
#             "width": 60
#           }
#         ],
#         "name": "Top 100 Germany Single Jahrescharts 2024",
#         "owner": {
#           "display_name": "Mister Mixmania",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/r26v0qtkcxs6q96mreuaa3mzs"
#           },
#           "href": "https://api.spotify.com/v1/users/r26v0qtkcxs6q96mreuaa3mzs",
#           "id": "r26v0qtkcxs6q96mreuaa3mzs",
#           "type": "user",
#           "uri": "spotify:user:r26v0qtkcxs6q96mreuaa3mzs"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AAAABdbnFO8hJ3KPjZ0/SRPnIh5tI3tW",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/48ovXYknwnw8ZLShQXgLOl/tracks",
#           "total": 100
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:48ovXYknwnw8ZLShQXgLOl"
#       },
#       null,
#       {
#         "collaborative": false,
#         "description": "Top Charts Music for Germany 2024., Radio and Lists 🇩🇪 Charts, Top Hits, Deutchland, Pop Hits, Radio, Best Covers, Musik, Popular Music, Adam Port, Eminem, Sabrina Carpenter, Benson Bones, Billie Eilish",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/6cCsr8ICcaaKkeB5lCCYzO"
#         },
#         "href": "https://api.spotify.com/v1/playlists/6cCsr8ICcaaKkeB5lCCYzO",
#         "id": "6cCsr8ICcaaKkeB5lCCYzO",
#         "images": [
#           {
#             "height": null,
#             "url": "https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84477a0584049642dbe551598b",
#             "width": null
#           }
#         ],
#         "name": "Charts Germany 2025 🇩🇪 Top Hits - Pop Hits - Top 100 Deutchland - Radio Songs ",
#         "owner": {
#           "display_name": "Hit Music Group",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/kpmvso2hddt008tdym03gycwi"
#           },
#           "href": "https://api.spotify.com/v1/users/kpmvso2hddt008tdym03gycwi",
#           "id": "kpmvso2hddt008tdym03gycwi",
#           "type": "user",
#           "uri": "spotify:user:kpmvso2hddt008tdym03gycwi"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AAAAFUjgJOQ6VQLnz4bbbDxLWBE9/izH",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/6cCsr8ICcaaKkeB5lCCYzO/tracks",
#           "total": 200
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:6cCsr8ICcaaKkeB5lCCYzO"
#       },
#       null
#     ]
#   }
# }

# %%
playlists = results['playlists']['items']
valid_playlists = [pl for pl in playlists if pl is not None]

for playlist in valid_playlists:
    print(f"Playlist Name: {playlist['name']}")
    print(f"Playlist ID: {playlist['id']}")
    print(f"Playlist URL: {playlist['external_urls']['spotify']}")
    print(f"Number of Tracks: {playlist['tracks']['total']}")
    print("------")
# Out:
# Playlist Name: CHARTS APRIL  2025
# Playlist ID: 5CiverItIyXTNNfYLXC01c
# Playlist URL: https://open.spotify.com/playlist/5CiverItIyXTNNfYLXC01c
# Number of Tracks: 60
# ------
# Playlist Name: Jahrescharts 2024 - Die Hits des Jahres · offizielle Top 100 Single-Charts 2024
# Playlist ID: 2ZSsc7fFT7J9GQbanZu29P
# Playlist URL: https://open.spotify.com/playlist/2ZSsc7fFT7J9GQbanZu29P
# Number of Tracks: 100
# ------
# Playlist Name: Hits 2025 🔥 🔥  Aktuelle Charts und die besten Songs 2025 🔝 🙌
# Playlist ID: 1CnDCN10TJZjw6K2H3gNRv
# Playlist URL: https://open.spotify.com/playlist/1CnDCN10TJZjw6K2H3gNRv
# Number of Tracks: 131
# ------
# Playlist Name: Radio Top  100 Germany 🎸 🎵  Airplay Charts 01.09.2024 REL, FFH iTunes, Harmony, Spotifý. DJ OKAY 14
# Playlist ID: 2jn393YA9LPM9o5I4rzfqD
# Playlist URL: https://open.spotify.com/playlist/2jn393YA9LPM9o5I4rzfqD
# Number of Tracks: 93
# ------
# Playlist Name: Top 100 Germany Single - Song Charts vom 18.04.25
# Playlist ID: 46w2ClivIbhMgdqyGSKwvY
# Playlist URL: https://open.spotify.com/playlist/46w2ClivIbhMgdqyGSKwvY
# Number of Tracks: 100
# ------
# Playlist Name: Top 100 Germany Single Jahrescharts 2024
# Playlist ID: 48ovXYknwnw8ZLShQXgLOl
# Playlist URL: https://open.spotify.com/playlist/48ovXYknwnw8ZLShQXgLOl
# Number of Tracks: 100
# ------
# Playlist Name: Charts Germany 2025 🇩🇪 Top Hits - Pop Hits - Top 100 Deutchland - Radio Songs
# Playlist ID: 6cCsr8ICcaaKkeB5lCCYzO
# Playlist URL: https://open.spotify.com/playlist/6cCsr8ICcaaKkeB5lCCYzO
# Number of Tracks: 200
# ------

# %% [markdown]
# ## Getting the track_id

# %%
playlist_id = "2ZSsc7fFT7J9GQbanZu29P" # Playlist: Charts 2025 🔥Top 100 Aktuelle Charts Radio Hits 2025
print(f"Playlist: {playlist['name']} (ID: {playlist_id})")
playlist_data = sp.playlist(playlist_id)
tracks = []

for idx, item in enumerate(playlist_data['tracks']['items'], start=1):
    track = item['track']
    track_name = track['name']
    artists = ", ".join(artist['name'] for artist in track['artists'])
    
    isrc = track.get('external_ids', {}).get('isrc', "NoN")
    track_id = track.get('id', "No ID")
    
    tracks.append([isrc, track_id, track_name, artists])


df_top2025_playlist = pd.DataFrame(tracks, columns=['isrc', 'track_id' , 'track_name', 'artists']) 
df_top2025_playlist
# Out:
# Playlist: Charts 2025 🔥Top 100 Aktuelle Charts Radio Hits 2025 - Musik Mix - Summer - Pop Songs - Top 2025 (ID: 2ZSsc7fFT7J9GQbanZu29P)
#             isrc                track_id  \
# 0   QZJ842400387  2GxrNKugF82CnoRFbQfzPf
# 1   DEA622401272  16f4ZN6XOfrIO8fJkm28HM
# 2   USWB12307016  6tNQ70jh4OwmPGpYy6R2o9
# 3   NLZ542301810  0h3Xy4V4apMraB5NuM8U7Z
# 4   DEA622301801  31nfdEooLEq7dn3UMcIeB5
# ..           ...                     ...
# 95  DEE860100979  0SvD6EdetxVtXei2JhkV4B
# 96  DEQ321900164  5dhQeuLGmlhfwlI6BWfSpo
# 97  DETX42400011  189vFQyTAhpSCsI07yjQVq
# 98  US53Q1200148  0jZO7p0nBUi9VHedWUBS9l
# 99  DECE72401331  0Rgdhptwk0A3Clbu5RpYI1
#
#                                            track_name  \
# 0                          i like the way you kiss me
# 1                                              Wunder
# 2                                    Beautiful Things
# 3                                        Stumblin' In
# 4                    Vois sur ton chemin - Techno Mix
# ..                                                ...
# 95  Wonderful Dream (Holidays Are Coming) - Radio ...
# 96                                             Roller
# 97                                      Abenteuerland
# 98           The Night We Met (feat. Phoebe Bridgers)
# 99                                            Starboy
#
#                         artists
# 0                       Artemas
# 1            AYLIVA, Apache 207
# 2                  Benson Boone
# 3                         CYRIL
# 4                       BENNETT
# ..                          ...
# 95             Melanie Thornton
# 96                   Apache 207
# 97    FiNCH, SDP, Phil The Beat
# 98  Lord Huron, Phoebe Bridgers
# 99              Luciano, Jazeek
#
# [100 rows x 4 columns]

# %%
# !pip install notebook ipython
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting notebook
#   Downloading notebook-7.4.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: ipython in /Users/sergej/Library/Python/3.9/lib/python/site-packages (8.18.1)
# Collecting jupyter-server<3,>=2.4.0 (from notebook)
#   Downloading jupyter_server-2.15.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from notebook)
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab<4.5,>=4.4.0rc0 (from notebook)
#   Downloading jupyterlab-4.4.1-py3-none-any.whl.metadata (16 kB)
# Collecting notebook-shim<0.3,>=0.2 (from notebook)
#   Downloading notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: tornado>=6.2.0 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from notebook) (6.4.2)
# Requirement already satisfied: decorator in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from ipython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from ipython) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from ipython) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from ipython) (2.19.1)
# Requirement already satisfied: stack-data in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from ipython) (5.14.3)
# Requirement already satisfied: typing-extensions in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from ipython) (4.12.2)
# Requirement already satisfied: exceptiongroup in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from ipython) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from ipython) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython) (0.8.4)
# Collecting anyio>=3.1.0 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.7.2)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting nbconvert>=6.4.4 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading nbconvert-7.16.6-py3-none-any.whl.metadata (8.5 kB)
# Collecting nbformat>=5.3.0 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: packaging>=22.0 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook) (24.2)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading prometheus_client-0.21.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyzmq>=24 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook) (26.2.1)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: websocket-client>=1.7 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.0)
# Collecting async-lru>=1.0.0 (from jupyterlab<4.5,>=4.4.0rc0->notebook)
#   Downloading async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpx>=0.25.0 (from jupyterlab<4.5,>=4.4.0rc0->notebook)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook) (8.6.1)
# Requirement already satisfied: ipykernel>=6.5.0 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook) (6.29.5)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<4.5,>=4.4.0rc0->notebook)
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: setuptools>=41.1.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook) (58.0.4)
# Collecting tomli>=1.2.2 (from jupyterlab<4.5,>=4.4.0rc0->notebook)
#   Downloading tomli-2.2.1-py3-none-any.whl.metadata (10 kB)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.27.1->notebook)
#   Downloading babel-2.17.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->notebook)
#   Downloading json5-0.12.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.32.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython) (0.2.3)
# Requirement already satisfied: idna>=2.8 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.1)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook)
#   Downloading argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl.metadata (6.7 kB)
# Requirement already satisfied: certifi in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from httpx>=0.25.0->jupyterlab<4.5,>=4.4.0rc0->notebook) (2025.1.31)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab<4.5,>=4.4.0rc0->notebook)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.5,>=4.4.0rc0->notebook)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: zipp>=3.20 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.8.3->jupyterlab<4.5,>=4.4.0rc0->notebook) (3.21.0)
# Requirement already satisfied: appnope in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.0rc0->notebook) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.0rc0->notebook) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.0rc0->notebook) (1.8.12)
# Requirement already satisfied: nest-asyncio in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.0rc0->notebook) (1.6.0)
# Requirement already satisfied: psutil in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.0rc0->notebook) (6.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.3.6)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading python_json_logger-3.3.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting pyyaml>=5.3 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading PyYAML-6.0.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: beautifulsoup4 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.13.4)
# Collecting bleach!=5.0.0 (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading mistune-3.1.3-py3-none-any.whl.metadata (1.8 kB)
# Collecting nbclient>=0.5.0 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading nbclient-0.10.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading fastjsonschema-2.21.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (2.3.0)
# Collecting webencodings (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting tinycss2<1.5,>=1.1.0 (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (1.15.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.7)
# Requirement already satisfied: pycparser in /Users/sergej/Library/Python/3.9/lib/python/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.22)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl.metadata (2.1 kB)
# Downloading notebook-7.4.1-py3-none-any.whl (14.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 4.9 MB/s eta 0:00:00a 0:00:01
# Downloading jupyter_server-2.15.0-py3-none-any.whl (385 kB)
# Downloading jupyterlab-4.4.1-py3-none-any.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 9.2 MB/s eta 0:00:00a 0:00:01
# Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
# Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Downloading babel-2.17.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 9.7 MB/s eta 0:00:0000:010:01
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading json5-0.12.0-py3-none-any.whl (36 kB)
# Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading nbconvert-7.16.6-py3-none-any.whl (258 kB)
# Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading prometheus_client-0.21.1-py3-none-any.whl (54 kB)
# Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Downloading tomli-2.2.1-py3-none-any.whl (14 kB)
# Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
# Downloading fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Downloading mistune-3.1.3-py3-none-any.whl (53 kB)
# Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Downloading PyYAML-6.0.2-cp39-cp39-macosx_11_0_arm64.whl (172 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl (53 kB)
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
# Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Installing collected packages: webencodings, fastjsonschema, webcolors, uri-template, types-python-dateutil, tomli, tinycss2, terminado, send2trash, rfc3986-validator, rfc3339-validator, pyyaml, python-json-logger, prometheus-client, pandocfilters, overrides, mistune, jupyterlab-pygments, jsonpointer, json5, h11, fqdn, defusedxml, bleach, babel, async-lru, anyio, jupyter-server-terminals, httpcore, arrow, argon2-cffi-bindings, isoduration, httpx, argon2-cffi, nbformat, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
# Successfully installed anyio-4.9.0 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.5 babel-2.17.0 bleach-6.2.0 defusedxml-0.7.1 fastjsonschema-2.21.1 fqdn-1.5.1 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 isoduration-20.11.0 json5-0.12.0 jsonpointer-3.0.0 jupyter-events-0.12.0 jupyter-lsp-2.2.5 jupyter-server-2.15.0 jupyter-server-terminals-0.5.3 jupyterlab-4.4.1 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 mistune-3.1.3 nbclient-0.10.2 nbconvert-7.16.6 nbformat-5.10.4 notebook-7.4.1 notebook-shim-0.2.4 overrides-7.7.0 pandocfilters-1.5.1 prometheus-client-0.21.1 python-json-logger-3.3.0 pyyaml-6.0.2 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 send2trash-1.8.3 terminado-0.18.1 tinycss2-1.4.0 tomli-2.2.1 types-python-dateutil-2.9.0.20241206 uri-template-1.3.0 webcolors-24.11.1 webencodings-0.5.1

# %% [markdown]
# ## Embedded track player

# %%
from IPython.display import IFrame

# %%
track_id = "2GxrNKugF82CnoRFbQfzPf"

iframe = IFrame(
    src=f"https://open.spotify.com/embed/track/{track_id}",
    width="300",
    height="380"
)


iframe
# Out:
#         <iframe
#             width="300"
#             height="380"
#             src="https://open.spotify.com/embed/track/2GxrNKugF82CnoRFbQfzPf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Getting the Audio features of a song

# %% [markdown]
# ## Building a Data frame of audio features

# %%
track_ids = df_top2025_playlist['track_id'].tolist()


audio_features_list = sp.audio_features(track_ids)


df_audio_features = pd.DataFrame(audio_features_list)

df_combined = pd.merge(df_top2025_playlist, df_audio_features, left_on='track_id', right_on='id', how='left')


print(df_combined.head())
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=2GxrNKugF82CnoRFbQfzPf,16f4ZN6XOfrIO8fJkm28HM,6tNQ70jh4OwmPGpYy6R2o9,0h3Xy4V4apMraB5NuM8U7Z,31nfdEooLEq7dn3UMcIeB5,59NraMJsLaMCVtwXTSia8i,1NifMX1JqCz9caJowG8dxq,7oQepKHmXDaPC3rgeLRvQu,3rUGC1vUpkDG9CZFHMur1t,3bK1zVFBKIzYjmptmI4NsJ,5uQ7de4EWjb3rkcFxyEOpu,5YWu6dt50Nieq8qi572RF8,6usohdchdzW9oML7VC4Uhk,3U5JVgI2x4rDyHGObzJfNf,64f3yNXsi2Vk76odcHCOnw,09CnYHiZ5jGT1wr1TXJ9Zt,2qSkIjg1o9h3YT9RAgYN75,0Z7nGFVCLfixWctgePsRk9,3pPMgoouYtezLiBTEeL9be,331l3xABO0HMr1Kkyh2LZq,1i07MlxQIuFSqNX3x3LkJH,48lxT5qJF0yYyf2z4wB4xW,5Z0UnEtpLDQyYlWwgi8m9C,086edN2nz8TjB3zddIdlPn,4gxAezF8MafmWSZ0KCsRGj,3ilgxZl5g7MOQCUiky3VOG,3JvKfv6T31zO0ini8iNItO,2PnlsTsOTLE5jnBnNe2K0A,6eP5ePtmxVuEs0lzKwLm8r,6dOtVTDdiauQNBQEDOtlAB,2HYFX63wP3otVIvopRS99Z,3Vr3zh0r7ALn8VLqCiRR10,7DSAEUvxU8FajXtRloy8M0,6yeZM8gyykjaf8w0GqRfK4,5wtSei6pJpDEB1iKqPHhfU,0LMwmV37RCmBO2so0szAFs,5qEGAHerczFt3HmL9lhh4j,2FQrifJ1N335Ljm3TjTVVf,5mjYQaktjmjcMKcUIcqz4s,3qcreqi8RaGqahtJSQDxNI,1BJJbSX6muJVF2AK7uH1x4,7AOJcugo17Kr1WUheSI6Oq,2sTXJinZQxl58tFCTYtEqa,3an1JVi8OsE0aG6dMS4Pes,6GrvlxquXWumwyNeZb1oZz,4HDC7Mo6uLTujRvHymiXDf,6mMB4wR6EQMAV1xzUYEoF2,0iB5f04XdJ2tcfhoVkeLV8,3AjSfp5FDvwtMU9XBsbS8j,30vg2QguPyaa7PcAJTn9YE,2FRnf9qhLbvw8fu4IBXx78,4xhsWYTOGcal8zt0J161CU,1kHVme7OVyPqhtdiLj2SI4,2gOVXniOMdunVdYk2NUQ4p,5sxiqHHGSVjmeg5SrLZcKA,5CGPOGyyF3XvyQwyqlJH0P,4uUG5RXrOk84mYEfFvj3cK,1LY3GhF0zxIVgbYEQjCbUO,42VsgItocQwOQC3XWZ8JNA,3pn5z4CvMz95uEysWBUYCc,7ciTcePUxWjBbaouXk7Bvf,3pyvUdSZvgrmZbXcEsL2bs,3qhlB30KknSejmIvZZLjOD,29vCE5UzdE8dzcJWbG2CsK,6u0F8YTqdUic3gMpgTcNDX,5N1C1ii0IsKp1Ux3OXUM8C,5nPbKG04fhLkIAjcPFaZq7,6XjDF6nds4DE2BBbagZol6,0WbMK4wrZ1wFSty9F7FCgu,6WbDwAoc5xr0kFflHZW0A4,1usHG4kvIPmpuGwTGLIQaI,7bkUa9kDFGxgCC7d36dzFI,2TE4xW3ImvpltVU0cPcKUn,2plbrEY59IikOBgBGLjaoe,2wvUmObLQbxClXFsuhw8Ns,2FbTZrdW0KGqH7TOdZRHiP,1cXo8i9dgutdqjhjz3Zwqq,1sNQMj0Dq0UHrryEQqP4OY,4MSj19TwYBLgDFj3ddEeco,0etibdCuQ7kHL94ratzFfr,4fLnoXqsxHZFvGKppc7kCr,7fzHQizxTqy8wTXwlrgPQQ,11eYmv0tA3wEoyD1Sad2Nv,3BKD1PwArikchz2Zrlp1qi,5f3DCz8dOQdTLxzh8QQuvV,3fgehc497TFqKH1zBL2YNK,3ovTEUMYEoiT8ikEMVXBmS,3Z3QhZAZpqwZa1phsbQ3JZ,5Tpojb1ynbO0MgfAwgDza5,5RKQ5NdjSh2QzD4MaunT91,7uoFMmxln0GPXQ0AcCBXRq,2uFaJJtFpPDc5Pa95XzTvg,1odExI7RdWc4BT515LTAwj,5496lks6V3fh1mZAB6IAap,3nAp4IvdMPPWEH9uuXFFV5,0SvD6EdetxVtXei2JhkV4B,5dhQeuLGmlhfwlI6BWfSpo,189vFQyTAhpSCsI07yjQVq,0jZO7p0nBUi9VHedWUBS9l,0Rgdhptwk0A3Clbu5RpYI1 with Params: {} returned 403 due to None
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/spotipy/client.py:274, in Spotify._internal_call(self, method, url, payload, params)
#     269 response = self._session.request(
#     270     method, url, headers=headers, proxies=self.proxies,
#     271     timeout=self.requests_timeout, **args
#     272 )
# --> 274 response.raise_for_status()
#     275 results = response.json()
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.spotify.com/v1/audio-features/?ids=2GxrNKugF82CnoRFbQfzPf,16f4ZN6XOfrIO8fJkm28HM,6tNQ70jh4OwmPGpYy6R2o9,0h3Xy4V4apMraB5NuM8U7Z,31nfdEooLEq7dn3UMcIeB5,59NraMJsLaMCVtwXTSia8i,1NifMX1JqCz9caJowG8dxq,7oQepKHmXDaPC3rgeLRvQu,3rUGC1vUpkDG9CZFHMur1t,3bK1zVFBKIzYjmptmI4NsJ,5uQ7de4EWjb3rkcFxyEOpu,5YWu6dt50Nieq8qi572RF8,6usohdchdzW9oML7VC4Uhk,3U5JVgI2x4rDyHGObzJfNf,64f3yNXsi2Vk76odcHCOnw,09CnYHiZ5jGT1wr1TXJ9Zt,2qSkIjg1o9h3YT9RAgYN75,0Z7nGFVCLfixWctgePsRk9,3pPMgoouYtezLiBTEeL9be,331l3xABO0HMr1Kkyh2LZq,1i07MlxQIuFSqNX3x3LkJH,48lxT5qJF0yYyf2z4wB4xW,5Z0UnEtpLDQyYlWwgi8m9C,086edN2nz8TjB3zddIdlPn,4gxAezF8MafmWSZ0KCsRGj,3ilgxZl5g7MOQCUiky3VOG,3JvKfv6T31zO0ini8iNItO,2PnlsTsOTLE5jnBnNe2K0A,6eP5ePtmxVuEs0lzKwLm8r,6dOtVTDdiauQNBQEDOtlAB,2HYFX63wP3otVIvopRS99Z,3Vr3zh0r7ALn8VLqCiRR10,7DSAEUvxU8FajXtRloy8M0,6yeZM8gyykjaf8w0GqRfK4,5wtSei6pJpDEB1iKqPHhfU,0LMwmV37RCmBO2so0szAFs,5qEGAHerczFt3HmL9lhh4j,2FQrifJ1N335Ljm3TjTVVf,5mjYQaktjmjcMKcUIcqz4s,3qcreqi8RaGqahtJSQDxNI,1BJJbSX6muJVF2AK7uH1x4,7AOJcugo17Kr1WUheSI6Oq,2sTXJinZQxl58tFCTYtEqa,3an1JVi8OsE0aG6dMS4Pes,6GrvlxquXWumwyNeZb1oZz,4HDC7Mo6uLTujRvHymiXDf,6mMB4wR6EQMAV1xzUYEoF2,0iB5f04XdJ2tcfhoVkeLV8,3AjSfp5FDvwtMU9XBsbS8j,30vg2QguPyaa7PcAJTn9YE,2FRnf9qhLbvw8fu4IBXx78,4xhsWYTOGcal8zt0J161CU,1kHVme7OVyPqhtdiLj2SI4,2gOVXniOMdunVdYk2NUQ4p,5sxiqHHGSVjmeg5SrLZcKA,5CGPOGyyF3XvyQwyqlJH0P,4uUG5RXrOk84mYEfFvj3cK,1LY3GhF0zxIVgbYEQjCbUO,42VsgItocQwOQC3XWZ8JNA,3pn5z4CvMz95uEysWBUYCc,7ciTcePUxWjBbaouXk7Bvf,3pyvUdSZvgrmZbXcEsL2bs,3qhlB30KknSejmIvZZLjOD,29vCE5UzdE8dzcJWbG2CsK,6u0F8YTqdUic3gMpgTcNDX,5N1C1ii0IsKp1Ux3OXUM8C,5nPbKG04fhLkIAjcPFaZq7,6XjDF6nds4DE2BBbagZol6,0WbMK4wrZ1wFSty9F7FCgu,6WbDwAoc5xr0kFflHZW0A4,1usHG4kvIPmpuGwTGLIQaI,7bkUa9kDFGxgCC7d36dzFI,2TE4xW3ImvpltVU0cPcKUn,2plbrEY59IikOBgBGLjaoe,2wvUmObLQbxClXFsuhw8Ns,2FbTZrdW0KGqH7TOdZRHiP,1cXo8i9dgutdqjhjz3Zwqq,1sNQMj0Dq0UHrryEQqP4OY,4MSj19TwYBLgDFj3ddEeco,0etibdCuQ7kHL94ratzFfr,4fLnoXqsxHZFvGKppc7kCr,7fzHQizxTqy8wTXwlrgPQQ,11eYmv0tA3wEoyD1Sad2Nv,3BKD1PwArikchz2Zrlp1qi,5f3DCz8dOQdTLxzh8QQuvV,3fgehc497TFqKH1zBL2YNK,3ovTEUMYEoiT8ikEMVXBmS,3Z3QhZAZpqwZa1phsbQ3JZ,5Tpojb1ynbO0MgfAwgDza5,5RKQ5NdjSh2QzD4MaunT91,7uoFMmxln0GPXQ0AcCBXRq,2uFaJJtFpPDc5Pa95XzTvg,1odExI7RdWc4BT515LTAwj,5496lks6V3fh1mZAB6IAap,3nAp4IvdMPPWEH9uuXFFV5,0SvD6EdetxVtXei2JhkV4B,5dhQeuLGmlhfwlI6BWfSpo,189vFQyTAhpSCsI07yjQVq,0jZO7p0nBUi9VHedWUBS9l,0Rgdhptwk0A3Clbu5RpYI1
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[23], line 4
#       1 track_ids = df_top2025_playlist['track_id'].tolist()
#       3 # Получаем аудио-характеристики для треков (Spotify позволяет запрашивать до 100 треков за один вызов)
# ----> 4 audio_features_list = sp.audio_features(track_ids)
#       6 # Конвертируем список словарей в DataFrame
#       7 df_audio_features = pd.DataFrame(audio_features_list)
#
# File ~/Library/Python/3.9/lib/python/site-packages/spotipy/client.py:1802, in Spotify.audio_features(self, tracks)
#    1800 else:
#    1801     tlist = [self._get_id("track", t) for t in tracks]
# -> 1802     results = self._get("audio-features/?ids=" + ",".join(tlist))
#    1803 # the response has changed, look for the new style first, and if
#    1804 # it's not there, fallback on the old style
#    1805 if "audio_features" in results:
#
# File ~/Library/Python/3.9/lib/python/site-packages/spotipy/client.py:324, in Spotify._get(self, url, args, payload, **kwargs)
#     321 if args:
#     322     kwargs.update(args)
# --> 324 return self._internal_call("GET", url, payload, kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/spotipy/client.py:294, in Spotify._internal_call(self, method, url, payload, params)
#     289         reason = None
#     291     logger.error(f"HTTP Error for {method} to {url} with Params: "
#     292                  f"{args.get('params')} returned {response.status_code} due to {msg}")
# --> 294     raise SpotifyException(
#     295         response.status_code,
#     296         -1,
#     297         f"{response.url}:\n {msg}",
#     298         reason=reason,
#     299         headers=response.headers,
#     300     )
#     301 except requests.exceptions.RetryError as retry_error:
#     302     request = retry_error.request
#
# SpotifyException: http status: 403, code: -1 - https://api.spotify.com/v1/audio-features/?ids=2GxrNKugF82CnoRFbQfzPf,16f4ZN6XOfrIO8fJkm28HM,6tNQ70jh4OwmPGpYy6R2o9,0h3Xy4V4apMraB5NuM8U7Z,31nfdEooLEq7dn3UMcIeB5,59NraMJsLaMCVtwXTSia8i,1NifMX1JqCz9caJowG8dxq,7oQepKHmXDaPC3rgeLRvQu,3rUGC1vUpkDG9CZFHMur1t,3bK1zVFBKIzYjmptmI4NsJ,5uQ7de4EWjb3rkcFxyEOpu,5YWu6dt50Nieq8qi572RF8,6usohdchdzW9oML7VC4Uhk,3U5JVgI2x4rDyHGObzJfNf,64f3yNXsi2Vk76odcHCOnw,09CnYHiZ5jGT1wr1TXJ9Zt,2qSkIjg1o9h3YT9RAgYN75,0Z7nGFVCLfixWctgePsRk9,3pPMgoouYtezLiBTEeL9be,331l3xABO0HMr1Kkyh2LZq,1i07MlxQIuFSqNX3x3LkJH,48lxT5qJF0yYyf2z4wB4xW,5Z0UnEtpLDQyYlWwgi8m9C,086edN2nz8TjB3zddIdlPn,4gxAezF8MafmWSZ0KCsRGj,3ilgxZl5g7MOQCUiky3VOG,3JvKfv6T31zO0ini8iNItO,2PnlsTsOTLE5jnBnNe2K0A,6eP5ePtmxVuEs0lzKwLm8r,6dOtVTDdiauQNBQEDOtlAB,2HYFX63wP3otVIvopRS99Z,3Vr3zh0r7ALn8VLqCiRR10,7DSAEUvxU8FajXtRloy8M0,6yeZM8gyykjaf8w0GqRfK4,5wtSei6pJpDEB1iKqPHhfU,0LMwmV37RCmBO2so0szAFs,5qEGAHerczFt3HmL9lhh4j,2FQrifJ1N335Ljm3TjTVVf,5mjYQaktjmjcMKcUIcqz4s,3qcreqi8RaGqahtJSQDxNI,1BJJbSX6muJVF2AK7uH1x4,7AOJcugo17Kr1WUheSI6Oq,2sTXJinZQxl58tFCTYtEqa,3an1JVi8OsE0aG6dMS4Pes,6GrvlxquXWumwyNeZb1oZz,4HDC7Mo6uLTujRvHymiXDf,6mMB4wR6EQMAV1xzUYEoF2,0iB5f04XdJ2tcfhoVkeLV8,3AjSfp5FDvwtMU9XBsbS8j,30vg2QguPyaa7PcAJTn9YE,2FRnf9qhLbvw8fu4IBXx78,4xhsWYTOGcal8zt0J161CU,1kHVme7OVyPqhtdiLj2SI4,2gOVXniOMdunVdYk2NUQ4p,5sxiqHHGSVjmeg5SrLZcKA,5CGPOGyyF3XvyQwyqlJH0P,4uUG5RXrOk84mYEfFvj3cK,1LY3GhF0zxIVgbYEQjCbUO,42VsgItocQwOQC3XWZ8JNA,3pn5z4CvMz95uEysWBUYCc,7ciTcePUxWjBbaouXk7Bvf,3pyvUdSZvgrmZbXcEsL2bs,3qhlB30KknSejmIvZZLjOD,29vCE5UzdE8dzcJWbG2CsK,6u0F8YTqdUic3gMpgTcNDX,5N1C1ii0IsKp1Ux3OXUM8C,5nPbKG04fhLkIAjcPFaZq7,6XjDF6nds4DE2BBbagZol6,0WbMK4wrZ1wFSty9F7FCgu,6WbDwAoc5xr0kFflHZW0A4,1usHG4kvIPmpuGwTGLIQaI,7bkUa9kDFGxgCC7d36dzFI,2TE4xW3ImvpltVU0cPcKUn,2plbrEY59IikOBgBGLjaoe,2wvUmObLQbxClXFsuhw8Ns,2FbTZrdW0KGqH7TOdZRHiP,1cXo8i9dgutdqjhjz3Zwqq,1sNQMj0Dq0UHrryEQqP4OY,4MSj19TwYBLgDFj3ddEeco,0etibdCuQ7kHL94ratzFfr,4fLnoXqsxHZFvGKppc7kCr,7fzHQizxTqy8wTXwlrgPQQ,11eYmv0tA3wEoyD1Sad2Nv,3BKD1PwArikchz2Zrlp1qi,5f3DCz8dOQdTLxzh8QQuvV,3fgehc497TFqKH1zBL2YNK,3ovTEUMYEoiT8ikEMVXBmS,3Z3QhZAZpqwZa1phsbQ3JZ,5Tpojb1ynbO0MgfAwgDza5,5RKQ5NdjSh2QzD4MaunT91,7uoFMmxln0GPXQ0AcCBXRq,2uFaJJtFpPDc5Pa95XzTvg,1odExI7RdWc4BT515LTAwj,5496lks6V3fh1mZAB6IAap,3nAp4IvdMPPWEH9uuXFFV5,0SvD6EdetxVtXei2JhkV4B,5dhQeuLGmlhfwlI6BWfSpo,189vFQyTAhpSCsI07yjQVq,0jZO7p0nBUi9VHedWUBS9l,0Rgdhptwk0A3Clbu5RpYI1:
#  None, reason: None

# %% [markdown]
# ## Searching a playlist

# %%
results = sp.search(q="Top 3000", type="playlist", limit=10 )

# %% [markdown]
# ## Extracting the songs of a playlist

# %% [markdown]
# Pagination using "next".
# When you collect songs from a playlist using sp.playlist_tracks, you're limited by the limit parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter offset allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function sp.next() does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key next on the results from any request.

# %%
playlists = results['playlists']['items']
valid_playlists = [pl for pl in playlists if pl is not None]

for playlist in valid_playlists:
    print(f"Playlist Name: {playlist['name']}")
    print(f"Playlist ID: {playlist['id']}")
    print(f"Playlist URL: {playlist['external_urls']['spotify']}")
    print(f"Number of Tracks: {playlist['tracks']['total']}")
    print("------")
# Out:
# Playlist Name: UPTEMPO HARDCORE | Uptempo united | BKJN | Partyraiser  | Snakepit |  Darkside Unleashed | Barbaric
# Playlist ID: 73JaoIo45mRg5Y6hKqVPWG
# Playlist URL: https://open.spotify.com/playlist/73JaoIo45mRg5Y6hKqVPWG
# Number of Tracks: 3429
# ------
# Playlist Name: Best of 2000/2010er🥳🤙
# Playlist ID: 0ZwpkWaYOmY8pdwC2SpI9c
# Playlist URL: https://open.spotify.com/playlist/0ZwpkWaYOmY8pdwC2SpI9c
# Number of Tracks: 560
# ------
# Playlist Name: Hempe‘s Top 3000
# Playlist ID: 5Oy8wUHuKEYQnyV4QPnq5A
# Playlist URL: https://open.spotify.com/playlist/5Oy8wUHuKEYQnyV4QPnq5A
# Number of Tracks: 3011
# ------
# Playlist Name: Top 1000 music songs
# Playlist ID: 4KfrZUiuT5EndmOJiLblhy
# Playlist URL: https://open.spotify.com/playlist/4KfrZUiuT5EndmOJiLblhy
# Number of Tracks: 384
# ------
# Playlist Name: I Adore You (feat. Daecolm) - HUGEL, Topic, Arash, Daecolm
# Playlist ID: 5PvrLwyy59oTXT0OtDHVqN
# Playlist URL: https://open.spotify.com/playlist/5PvrLwyy59oTXT0OtDHVqN
# Number of Tracks: 11
# ------
# Playlist Name: 100+ Million Streams [Top 50 ordered by Streams] | Most played tracks on Spotify | BIGGEST PLAYLIST)
# Playlist ID: 0nwC4WbX0wGfH1Asj185R6
# Playlist URL: https://open.spotify.com/playlist/0nwC4WbX0wGfH1Asj185R6
# Number of Tracks: 10000
# ------
# Playlist Name: Top 3000
# Playlist ID: 5H9JvguwHhUJ7jyvuGsuK6
# Playlist URL: https://open.spotify.com/playlist/5H9JvguwHhUJ7jyvuGsuK6
# Number of Tracks: 1554
# ------
# Playlist Name: Top2000 2024
# Playlist ID: 0wtMUPPMMr5lxdjfL9KgFx
# Playlist URL: https://open.spotify.com/playlist/0wtMUPPMMr5lxdjfL9KgFx
# Number of Tracks: 163
# ------
# Playlist Name: Michael Top 30000
# Playlist ID: 5iJfhqNSLFGvCpPu7l6HvI
# Playlist URL: https://open.spotify.com/playlist/5iJfhqNSLFGvCpPu7l6HvI
# Number of Tracks: 580
# ------

# %%
playlist_id = "0nwC4WbX0wGfH1Asj185R6"  
tracks_data = []  
limit = 100  
offset = 0  


results = sp.playlist_tracks(playlist_id, limit=limit, offset=offset)

while results:
    for item in results["items"]:
        track = item["track"]
        track_name = track["name"]
        artists = ", ".join(artist["name"] for artist in track["artists"])
        track_id = track["id"]
        isrc = track.get("external_ids", {}).get("isrc", "NaN")
        popularity = track.get("popularity", "NaN") 

        tracks_data.append([track_id, track_name, artists, isrc, popularity])

    
    if results["next"]:
        results = sp.next(results)  
    else:
        break  


df_tracks = pd.DataFrame(tracks_data, columns=["Track ID", "Titel", "Artist", "ISRC", "Popularity"])

# %%
df_tracks
# Out:
#                     Track ID                        Titel  \
# 0     0sf12qNH5qcw8qpgymFOqD              Blinding Lights
# 1     0FE9t6xYkqWXU2ahLh6D8X                 Shape of You
# 2     2TIlqbIneP0ZY1O0EzYLlc            Someone You Loved
# 3     4LRPiXqCikLlN15c3yImP7                    As It Was
# 4     7lQqaqZu0vjxzpdATOIsDt                      Starboy
# ...                      ...                          ...
# 9995  3JG1uFc40wfyrqaWC7iv0e   i like the way you kiss me
# 9996  1qFb85QhwOqpnAKh7ahsGQ                      Smother
# 9997  69HICMmc6nNLucAx3aJX9M  Thank God I'm a Country Boy
# 9998  6zzdyvVWjGrQBraSvuqJPY                  Starry Eyes
# 9999  7at9s1qowhUrFaE3qsr4WY             SUGA's Interlude
#
#                      Artist          ISRC  Popularity
# 0                The Weeknd  USUG11904206          25
# 1                Ed Sheeran  GBAHS1600463           8
# 2             Lewis Capaldi  DEUM71807062          72
# 3              Harry Styles  USSM12200612          19
# 4     The Weeknd, Daft Punk  USUG11600976           2
# ...                     ...           ...         ...
# 9995                Artemas  QZJ842400387          79
# 9996               Daughter  GBAFL1200259          54
# 9997            John Denver  USRC17407659          68
# 9998             The Weeknd  USUG12106693          64
# 9999      Halsey, SUGA, BTS  USUM71918762          40
#
# [10000 rows x 5 columns]

# %%
df_tracks.to_csv("spotify_playlist_10000_tracks.csv", index=False, encoding="utf-8")

print("✅ Saved into 'spotify_playlist_tracks.csv'!")
# Out:
# ✅ Saved into 'spotify_playlist_tracks.csv'!

# %% [markdown]
# ### Chopping a big playlist into chunks

# %%
from spotipy.exceptions import SpotifyException

def chunk_list(lst, chunk_size):
    for i in range(0, len(lst), chunk_size):
        yield lst[i:i + chunk_size]

chunked_ids = list(chunk_list(valid_track_ids, 10)) 


all_audio_features = []
for chunk in chunked_ids:
    try:
        features = sp.audio_features(chunk)
        all_audio_features.extend(features)
    except SpotifyException as e:
        print(f"Error chunck {chunk}: {e}")

        for tid in chunk:
            try:
                feat = sp.audio_features([tid])
                all_audio_features.extend(feat)
            except SpotifyException as e2:
                print(f"Error track {tid}: {e2}")


df_audio_features = pd.DataFrame(all_audio_features)
print(df_audio_features.head())

# Raise because Spotify closed audio features API in 2024

# %% [markdown]
# ### Example with rock

# %%
results = sp.search(q="rock", type="playlist", limit=20 )

playlists = results['playlists']['items']
valid_playlists = [pl for pl in playlists if pl is not None]

for playlist in valid_playlists:
    print(f"Playlist Name: {playlist['name']}")
    print(f"Playlist ID: {playlist['id']}")
    print(f"Playlist URL: {playlist['external_urls']['spotify']}")
    print(f"Number of Tracks: {playlist['tracks']['total']}")
    print("------")
# Out:
# Playlist Name: 100 Greatest Rock Songs
# Playlist ID: 61jNo7WKLOIQkahju8i0hw
# Playlist URL: https://open.spotify.com/playlist/61jNo7WKLOIQkahju8i0hw
# Number of Tracks: 113
# ------
# Playlist Name: ROCK  PARTY🤘🏼
# Playlist ID: 5OOdrDDDMy7bFkuknydpEJ
# Playlist URL: https://open.spotify.com/playlist/5OOdrDDDMy7bFkuknydpEJ
# Number of Tracks: 339
# ------
# Playlist Name: PAW Patrol - Alle Hörspiele (inkl. Neuheiten)
# Playlist ID: 667T6DMs73xTA5BhczMHYR
# Playlist URL: https://open.spotify.com/playlist/667T6DMs73xTA5BhczMHYR
# Number of Tracks: 2070
# ------
# Playlist Name: Rocky Training
# Playlist ID: 6pnjjHaIuQ1HqB9tIoCMay
# Playlist URL: https://open.spotify.com/playlist/6pnjjHaIuQ1HqB9tIoCMay
# Number of Tracks: 17
# ------
# Playlist Name: Die drei ??? - Die drei Fragezeichen - Alle Hörspiele
# Playlist ID: 5e6XxV3vhHhdfqcjXScH8o
# Playlist URL: https://open.spotify.com/playlist/5e6XxV3vhHhdfqcjXScH8o
# Number of Tracks: 9374
# ------
# Playlist Name: Top 100 Rock Classics: 80s, 90s & 2000s
# Playlist ID: 4RogSQVuCDyBU4D8JRckyt
# Playlist URL: https://open.spotify.com/playlist/4RogSQVuCDyBU4D8JRckyt
# Number of Tracks: 91
# ------
# Playlist Name: Rock’n Roll BEST OF
# Playlist ID: 72Jj1IPNGZVqPvlqo53rMU
# Playlist URL: https://open.spotify.com/playlist/72Jj1IPNGZVqPvlqo53rMU
# Number of Tracks: 32
# ------
# Playlist Name: Rocky Horror Picture Show Soundtrack
# Playlist ID: 3zoXL386C98ack345Ys9aK
# Playlist URL: https://open.spotify.com/playlist/3zoXL386C98ack345Ys9aK
# Number of Tracks: 20
# ------
# Playlist Name: COUNTRY HITS 2025 🔥 New Country Songs + Top Hits
# Playlist ID: 4Jb4PDWREzNnbZcOHPcZPy
# Playlist URL: https://open.spotify.com/playlist/4Jb4PDWREzNnbZcOHPcZPy
# Number of Tracks: 119
# ------
# Playlist Name: Rock am Ring 2025 | Official Playlist
# Playlist ID: 2WCruA7PSHS4QH5jwB3ITK
# Playlist URL: https://open.spotify.com/playlist/2WCruA7PSHS4QH5jwB3ITK
# Number of Tracks: 291
# ------
# Playlist Name: Classic Rock Songs 60s 70s 80s 90s
# Playlist ID: 6b2dBnxolvwV2L1L4thWRm
# Playlist URL: https://open.spotify.com/playlist/6b2dBnxolvwV2L1L4thWRm
# Number of Tracks: 512
# ------

# %% [markdown]
# ## Optional(Extra)

# %% [markdown]
# ## Getting the artists of the playlist

# %%
playlist_id = "61jNo7WKLOIQkahju8i0hw" 
tracks = []
limit = 100 
offset = 0

results = sp.playlist_tracks(playlist_id, limit=limit, offset=offset)
tracks.extend(results['items'])

while results['next']:
    results = sp.next(results)
    tracks.extend(results['items'])

artist_counts = {}

for item in tracks:
 
    track = item.get('track')
    if not track:
        continue
    for artist in track.get('artists', []):
        artist_name = artist.get('name')
        if artist_name:
            artist_counts[artist_name] = artist_counts.get(artist_name, 0) + 1


df_artists = pd.DataFrame(list(artist_counts.items()), columns=["Artist", "Track Count"])


df_artists = df_artists.sort_values(by="Track Count", ascending=False)

df_artists.head(20)
# Out:
#                    Artist  Track Count
# 0   Red Hot Chili Peppers            5
# 25          Fleetwood Mac            4
# 13            Linkin Park            4
# 12              Green Day            3
# 62          Guns N' Roses            3
# 20                  Queen            3
# 15                  AC/DC            3
# 1            Led Zeppelin            3
# 8                  Eagles            2
# 23         The Black Keys            2
# 30                   Muse            2
# 2       The Goo Goo Dolls            2
# 6         Matchbox Twenty            2
# 41             Nickelback            2
# 60              The Clash            2
# 26              blink-182            2
# 17                Nirvana            2
# 3             David Bowie            2
# 19     The Rolling Stones            2
# 21                 Prince            2

# %% [markdown]
# # Getting albums

# %% [markdown]
# In this section we will work with albums to extract information. We will start by extracting all the albums of an artist.

# %%
search_result = sp.search(q="artist:Coldplay", type="artist", limit=1)
artist = search_result['artists']['items'][0]
artist_id = artist['id']
print(f"ID artist {artist['name']}: {artist_id}")


albums = []
results = sp.artist_albums(artist_id, album_type='album', limit=50)
albums.extend(results['items'])

while results['next']:
    results = sp.next(results)
    albums.extend(results['items'])

unique_albums = {}
for album in albums:
    key = (album["name"], album["release_date"])
    unique_albums[key] = album

albums_list = list(unique_albums.values())


df_albums = pd.DataFrame(albums_list)
df_albums = df_albums[['name', 'album_type', 'release_date', 'total_tracks', 'id']]

print("Coldplay albums:")
df_albums
# Out:
# ID artist Coldplay: 4gzpq5DPGxSnKTe4SA8HAU
# Coldplay albums:
#                                          name album_type release_date  \
# 0                                  Moon Music      album   2024-10-04
# 1              Moon Music (Full Moon Edition)      album   2024-10-03
# 2                        Music Of The Spheres      album   2021-10-15
# 3                               Everyday Life      album   2019-11-22
# 4                        Live in Buenos Aires      album   2018-12-07
# 5                       A Head Full of Dreams      album   2015-12-04
# 6                     Ghost Stories Live 2014      album   2014-11-21
# 7                               Ghost Stories      album   2014-05-16
# 8                                   Live 2012      album   2012-11-16
# 9                                 Mylo Xyloto      album   2011-10-24
# 10              LeftRightLeftRightLeft (Live)      album   2009-05-15
# 11    Viva La Vida (Prospekt's March Edition)      album   2008-11-24
# 12  Viva La Vida or Death and All His Friends      album   2008-06-19
# 13                                        X&Y      album   2005-06-07
# 14                                  Live 2003      album   2003-11-01
# 15                A Rush of Blood to the Head      album   2002-08-27
# 16                                 Parachutes      album   2000-07-10
#
#     total_tracks                      id
# 0             10  5SGtrmYbIo0Dsg4kJ4qjM6
# 1             20  1PdMoahMiMnqWfzWZs3xSI
# 2             12  06mXfvDsRZNfnsGZvX2zpb
# 3             16  2FeyIYDDAQqcOJKOKhvHdr
# 4             24  19CvkGjYpifkdwgVJSbog2
# 5             11  3cfAM8b8KqJRoIzt3zLKqw
# 6              9  1hNS0RsxPTFjmKXCgmjSLS
# 7              9  2G4AUqfwxcV1UdQjm2ouYr
# 8             15  2OkEsqGTfu8PWRrNHzfr0m
# 9             14  2R7iJz5uaHjLEVnMkloO18
# 10             9  3pboBm7GTa6V5dFXXCt52b
# 11            18  6JlhIoegCcjtdbTQbypS8R
# 12            10  0cnd1tlGnbfScH1KWwgxan
# 13            13  4E7bV0pzG0LciBSWTszra6
# 14            12  3JMOZD2qixTTLRW9I6JuF4
# 15            11  0RHX9XECH8IVI3LNgWDpmQ
# 16            10  6ZG5lRT77aJ3btmArcykra

# %% [markdown]
# Example: Coldplay

# %% [markdown]
# ## Getting the songs of a given album

# %%
album_id = "5SGtrmYbIo0Dsg4kJ4qjM6" 

tracks_data = []


results = sp.album_tracks(album_id, limit=50, offset=0)
tracks_data.extend(results["items"])


while results["next"]:
    results = sp.next(results)
    tracks_data.extend(results["items"])


df_tracks = pd.DataFrame(tracks_data)
df_tracks = df_tracks[['track_number', 'name', 'id', 'duration_ms']]


df_tracks
# Out:
#    track_number                      name                      id  duration_ms
# 0             1                MOON MUSiC  41FNZsY7w7KaTQ2bjxdR6w       276476
# 1             2  feelslikeimfallinginlove  49S3znqBAQyPyMpEuKeyJ6       236230
# 2             3                   WE PRAY  7xrEnNo99wrmIs8ZK3RZMK       233406
# 3             4                   JUPiTER  3EbRbM7qyJq9qjRqDIwBTO       240508
# 4             5             GOOD FEELiNGS  65wzicJctsW9GwnTnLWxQO       217380
# 5             6                         🌈  5lCyER2g9iYp4ozZ7iOKat       369598
# 6             7                      iAAM  1uwmf1x4LQLGv1P1xjJFYk       183371
# 7             8                   AETERNA  4EGl6H86WFalKVWSXbheb2       253028
# 8             9               ALL MY LOVE  6iYxkBHyMpsgVxUgfy5fSx       222647
# 9            10                 ONE WORLD  7HFJpnjKUS7LGl8NiyfUE3       407656
